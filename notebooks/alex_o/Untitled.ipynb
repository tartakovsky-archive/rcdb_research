# %%
from commons.utils import *
import pandas as pd
df = pd.DataFrame([1, 2, 3])
df

b = store_df_to_hdf_bytes(df)
get_df_from_hdf_bytes(b)
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
from commons.ohlcv import OHLCV


df = OHLCV.fetch("BTC", "USD", "bitfinex", "1m", ohlcv_api_url="test-back")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f2c831dbe552> in <module>
# ----> 1 from commons.ohlcv import OHLCV
#       2
#       3
#       4 df = OHLCV.fetch("BTC", "USD", "bitfinex", "1m", ohlcv_api_url="test-back")
#       5 df
#
# ModuleNotFoundError: No module named 'commons'
